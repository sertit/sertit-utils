# %%
from sertit.unistra import unistra_s3
from sertit import AnyPath
from sertit import rasters

with unistra_s3():
    pth = AnyPath("s3://sertit-sertit-utils-ci/tutorials/getting_started/image.tif")
    r = rasters.read(pth)

# %%
r[0:2,:,:]
# Out:
# <xarray.DataArray 'image' (band: 2, y: 1497, x: 2224)> Size: 27MB
# dask.array<getitem, shape=(2, 1497, 2224), dtype=float32, chunksize=(1, 1497, 2224), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 16B 1 2
#   * x            (x) float64 18kB 3.487e+05 3.487e+05 ... 3.931e+05 3.931e+05
#   * y            (y) float64 12kB 3.965e+06 3.965e+06 ... 3.935e+06 3.935e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
r[0:3, ::10, ::10].plot.imshow(robust=True)

# %%
r.data
# Out:
# dask.array<where, shape=(5, 1497, 2224), dtype=float32, chunksize=(1, 1497, 2224), chunktype=numpy.ndarray>

# %%
# Print x and y coordinates
print("X coordinates:\n", r.x)
print("\n\nY ccordinates: ", r.y)
# Out:
# X coordinates:
#  <xarray.DataArray 'x' (x: 2224)> Size: 18kB
# array([348659.997752, 348679.993255, 348699.988759, ..., 393070.011241,
#        393090.006745, 393110.002248])
# Coordinates:
#   * x            (x) float64 18kB 3.487e+05 3.487e+05 ... 3.931e+05 3.931e+05
#     spatial_ref  int64 8B 0
#
#
# Y ccordinates:  <xarray.DataArray 'y' (y: 1497)> Size: 12kB
# array([3964760.00334, 3964740.01002, 3964720.0167 , ..., 3934889.9833 ,
#        3934869.98998, 3934849.99666])
# Coordinates:
#   * y            (y) float64 12kB 3.965e+06 3.965e+06 ... 3.935e+06 3.935e+06
#     spatial_ref  int64 8B 0

# %%
# print the value of the pixels in the image
r.data
# Out:
# dask.array<where, shape=(5, 1497, 2224), dtype=float32, chunksize=(1, 1497, 2224), chunktype=numpy.ndarray>

# %%
# The spatial reference is stored in the coordinates of our raster and not in attributes !
r.spatial_ref
# Out:
# <xarray.DataArray 'spatial_ref' ()> Size: 8B
# array(0)
# Coordinates:
#     spatial_ref  int64 8B 0
# Attributes:
#     spatial_ref:   PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["WGS_...
#     crs_wkt:       PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["WGS_...
#     GeoTransform:  348650.0 19.9955035971223 0.0 3964770.0 0.0 -19.9933199732...

# %%
# So finally what are the attributes of our array ?
r.attrs
# Ok not really interisting...
# Out:
# {'AREA_OR_POINT': 'Area', 'scale_factor': 1.0, 'add_offset': 0.0}

# %%
from sertit import vectors

with unistra_s3():
    aoi_path = AnyPath("s3://sertit-sertit-utils-ci/tutorials/getting_started/aoi.shp")
    aoi = vectors.read(aoi_path)

# %%
aoi
# Out:
#    id                                           geometry
# 0 NaN  POLYGON ((366868.619 3952756.559, 376331.609 3...

# %%
aoi.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3dec3ddd6be358cd3080ad716b91808c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3dec3ddd6be358cd3080ad716b91808c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3dec3ddd6be358cd3080ad716b91808c = L.map(
#                 &quot;map_3dec3ddd6be358cd3080ad716b91808c&quot;,
#                 {
#                     center: [35.66906304428855, -118.41694453075078],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3dec3ddd6be358cd3080ad716b91808c);
#
#
#
#
#
#             var tile_layer_ac960f2c12127badbf87341d599acda7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ac960f2c12127badbf87341d599acda7.addTo(map_3dec3ddd6be358cd3080ad716b91808c);
#
#
#             map_3dec3ddd6be358cd3080ad716b91808c.fitBounds(
#                 [[35.62835648900074, -118.47171711856464], [35.709769599576354, -118.36217194293694]],
#                 {}
#             );
#
#
#         function geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac = L.geoJson(null, {
#                 onEachFeature: geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_onEachFeature,
#
#                 style: geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_styler,
#                 pointToLayer: geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_pointToLayer,
#         });
#
#         function geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_add (data) {
#             geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac
#                 .addData(data);
#         }
#             geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac_add({&quot;bbox&quot;: [-118.47171711856464, 35.62835648900074, -118.36217194293694, 35.709769599576354], &quot;features&quot;: [{&quot;bbox&quot;: [-118.47171711856464, 35.62835648900074, -118.36217194293694, 35.709769599576354], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.47171711856464, 35.709769599576354], [-118.3670805258881, 35.70781183230275], [-118.36217194293694, 35.62835648900074], [-118.47171711856464, 35.709769599576354]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;id&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_b7ec14854a7787b1fa86b14c6f8dd5ac.bindTooltip(
#     function(layer){

# %%
print(type(aoi))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
print("Estimate CRS is: ", aoi.estimate_utm_crs())
# Out:
# Estimate CRS is:  EPSG:32611

# %%
crop_image = rasters.crop(r, aoi)
crop_image[0:3, ::10, ::10].plot.imshow(robust=True)

# %%
rasters.write(crop_image, "crop_image.tif")

# %%
import xarray
from sertit.unistra import unistra_s3
from sertit import AnyPath
from sertit import rasters

with unistra_s3():
    pth = AnyPath("s3://sertit-sertit-utils-ci/tutorials/getting_started/MeanSoilLoss.tif")
    r = rasters.read(pth)

conditions = [
    (r.data < 6.7),
    (r.data >= 6.7) & (r.data < 11.2),
    (r.data >= 11.2) & (r.data < 22.4),
    (r.data >= 22.4) & (r.data < 33.6),
    (r.data >= 33.6),
]
for i, condition in enumerate(conditions):
    r.data = xarray.where(condition, i + 1, r.data)

# %%
# dask array processes are lazy. The cell above does not perform anything. 
# We can explicitely call compute() to load the result in memory
# but some methods implicitely call it (plot, write)
# r = r.compute()

# %%
r
# Out:
# <xarray.DataArray 'MeanSoilLoss' (band: 1, y: 1820, x: 1819)> Size: 26MB
# dask.array<where, shape=(1, 1820, 1819), dtype=float64, chunksize=(1, 1820, 1819), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 15kB 3.624e+05 3.625e+05 ... 3.806e+05 3.806e+05
#   * y            (y) float64 15kB 5.381e+06 5.381e+06 ... 5.363e+06 5.363e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
# The plot method actually calls compute()
r.plot()
